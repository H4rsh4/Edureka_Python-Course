# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
DATA_PATH = 'E:/Edureka_Python-Course/Data Sources/Day_4/'

# %%
df_raw = pd.read_csv(DATA_PATH+'BigMartSalesData.csv', low_memory=False)
df_raw
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541869    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541870    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541871    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541872    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541873    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#         UnitPrice  Amount InvoiceDate  Day  Month  Year  CustomerID  \
# ...

# %%
#Total Sales Per Month for Year 2011
data_from_2011 = df_raw[df_raw['Year'] == 2011]
data_from_2011
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 42479     539993     22386          JUMBO BAG PINK POLKADOT        10
# 42480     539993     21499               BLUE POLKADOT WRAP        25
# 42481     539993     21498              RED RETROSPOT WRAP         25
# 42482     539993     22379         RECYCLING BAG RETROSPOT          5
# 42483     539993     20718        RED RETROSPOT SHOPPER BAG        10
# ...          ...       ...                              ...       ...
# 541869    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541870    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541871    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541872    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541873    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#         UnitPrice  Amount InvoiceDate  Day  Month  Year  CustomerID  \
# ...

# %%
x_q1 = [round(sum(data_from_2011.Amount[data_from_2011.Month == i]), 2) for i in sorted(data_from_2011.Month.unique())]
y_q1 = sorted(data_from_2011.Month.unique())

# %%
x_q1
# Out:
# [822669.64,
#  549134.46,
#  752003.31,
#  582318.45,
#  817655.2,
#  832231.67,
#  757108.94,
#  791173.02,
#  1097467.72,
#  1239237.26,
#  1557236.41,
#  843909.02]

# %%
plt.plot(y_q1, x_q1, 'b-')

#Month 2 has the lowest Sales

# %%
months_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep' ,'Oct', 'Nov', 'Dec' ]
bar_plot = plt.bar(y_q1, x_q1, tick_label=months_names, )

#Both are good various puposed; Bar chart is good for visualizing sales per month
#And the basic plot can help identify trends in the data much better

# %%
labels = data_from_2011.Country.unique()
sizes = [round(sum(data_from_2011.Amount[data_from_2011.Country == i]), 2) for i in labels]
explode = [0.1 if i != max(sizes) else 0 for i in sizes]

plt.pie(sizes, explode=explode, labels=labels, startangle=90, shadow=True)

#United Kingdom is highest contributor
# Out:
# ([<matplotlib.patches.Wedge at 0x15947047c40>,
# ...
#  [Text(-0.5132046209977872, -0.9729445086881974, 'United Kingdom'),
#   Text(0.9833041851108292, 0.687832014043784, 'Sweden'),
#   Text(0.9725500714476614, 0.7029554456202391, 'Italy'),
#   Text(0.9614597525403471, 0.7180495416369646, 'Portugal'),
#   Text(0.9063634530503243, 0.7864510734779965, 'France'),
#   Text(0.8453953715557423, 0.8516493795877085, 'Belgium'),
#   Text(0.8351719522862906, 0.8616773236625798, 'Bahrain'),
#   Text(0.7772542974360842, 0.9142624115193293, 'Germany'),
#   Text(0.6305192266896391, 1.0210022060577046, 'EIRE'),
#   Text(0.4957071760736298, 1.0928286213259184, 'Australia'),
#   Text(0.42856004005589005, 1.1208640827804655, 'Spain'),
#   Text(0.3958507675921438, 1.132829276544666, 'Japan'),
#   Text(0.38247298768208754, 1.1374156732230913, 'Israel'),
#   Text(0.375488934347709, 1.1397403477031172, 'Cyprus'),
#   Text(0.27662997487636576, 1.1676796893839945, 'Netherlands'),
# ...

# %%
plt.scatter(df_raw.InvoiceDate, df_raw.Amount, c='r')
#Most of the invoice amount is in the range of 0-25000 dollars
