# %%
PATH_TO_DATA = 'E:/Edureka_Python-Course/Data Sources/Day_4/'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Question 1
hurricane_df_raw = pd.read_csv(PATH_TO_DATA+'Hurricanes.csv', low_memory=False)
hurricane_df_raw.head()
plt.plot(hurricane_df_raw.Year, hurricane_df_raw.Hurricanes)

# %%
#Question 2
citytemps_df_raw = pd.read_csv(PATH_TO_DATA+'CityTemps.csv',low_memory=False)
citytemps_df_raw.head()
# Out:
#    Year  Month  Moscow  Melbourne  San Francisco
# 0  2014      1    -8.6       22.0           12.8
# 1  2014      2    -1.9       21.5           12.7
# 2  2014      3     2.8       19.5           15.0
# 3  2014      4     7.0       15.8           15.7
# 4  2014      5    16.0       13.9           17.5

# %%
plt.hist([citytemps_df_raw.Moscow,
          citytemps_df_raw['San Francisco']
         ],
         orientation='vertical',
         color=['b', 'r'],
        )
# Out:
# (array([[1., 2., 4., 3., 3., 1., 0., 3., 4., 3.],
#         [0., 0., 0., 0., 0., 0., 1., 9., 6., 8.]]),
#  array([-8.6 , -5.63, -2.66,  0.31,  3.28,  6.25,  9.22, 12.19, 15.16,
#         18.13, 21.1 ]),
#  <a list of 2 BarContainer objects>)

# %%
m4_3_df_raw = pd.read_csv(PATH_TO_DATA+'data_file.txt',low_memory=False)
m4_3_df_raw
m4_3_df_raw.to_csv('m4_3_csv_data.csv')

# %%
X = [1,2,3,4]
Y = [20, 21, 20.5, 20.8]

# %%
#5.1
plt.plot(X,Y)

# %%
#5.2
plt.plot(X,Y, 'k--')

# %%
#5.3
plt.plot(X,Y, 'k--')

# %%
#5.4
plt.plot(X,Y, 'r-')
plt.yticks(ticks=[20.0,20.5,21.0 ])
plt.xticks(ticks=[1,2,3,4])
# Out:
# ([<matplotlib.axis.XTick at 0x29d0901f850>,
# ...
#  [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %%
#5.5
plt.plot(X,Y, 'r-')
plt.title('Sample Plot')
plt.yticks(ticks=[20.0,20.5,21.0 ])
plt.ylabel('Y-Axis')
plt.xticks(ticks=[1,2,3,4])
plt.xlabel('X-Axis')
# Out:
# Text(0.5, 0, 'X-Axis')

# %%
#5.6
plt.plot(X,Y, 'r-')
plt.title('Sample Plot')
plt.yticks(ticks=[20.0,20.5,21.0 ])
plt.ylabel('Y-Axis')
plt.xticks(ticks=[1,2,3,4])
plt.xlabel('X-Axis')
plt.errorbar(X, [0.12, 0.13, 0.2, 0.1])
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
#5.7
fig, ax = plt.subplots(1,1,figsize=(4,5), dpi=100)
ax.plot(X,Y)
#plt.title('Sample Plot')
#plt.yticks(ticks=[20.0,20.5,21.0 ])
#plt.ylabel('Y-Axis')
#plt.xticks(ticks=[1,2,3,4])
#plt.xlabel('X-Axis')
#plt.errorbar(X, [0.12, 0.13, 0.2, 0.1])

# %%
#5.8
fig, ax = plt.subplots(1,1,figsize=(4,5), dpi=100,)
ax.set_title(label='Sample font')
ax.set_xlabel('X-Axis')
ax.set_ylabel('Y-Axis')
ax.title.set_fontsize(14)
ax.plot(np.random.randint(50, size=10),np.random.randint(10, size=10))

# %%
#5.9
m4_5_9_df = pd.DataFrame({'first_name': [
'Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'], 
'female': [0, 1, 1, 0, 1],
'age': [42, 52, 36, 24, 73], 
'preTestScore': [4, 24, 31, 2, 3],
'postTestScore': [25, 94, 57, 62, 70]})

m4_5_9_df
# Out:
#   first_name last_name  female  age  preTestScore  postTestScore
# 0      Jason    Miller       0   42             4             25
# 1      Molly  Jacobson       1   52            24             94
# 2       Tina       Ali       1   36            31             57
# 3       Jake    Milner       0   24             2             62
# 4        Amy     Cooze       1   73             3             70

# %%
m4_5_9_X = m4_5_9_df.preTestScore
m4_5_9_Y = m4_5_9_df.postTestScore
size = [i for i in m4_5_9_df.age]
plt.scatter(m4_5_9_X, m4_5_9_Y, )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-98e301124ad0> in <module>
#       3 size = [i for i in m4_5_9_df.age]
#       4 plt.scatter(m4_5_9_X, m4_5_9_Y, )
# ----> 5 plt.set_cmap(size)
#
# E:\Edureka_Python-Course\edu-py\lib\site-packages\matplotlib\pyplot.py in set_cmap(cmap)
#    2216     matplotlib.cm.get_cmap
#    2217     """
# -> 2218     cmap = cm.get_cmap(cmap)
#    2219
#    2220     rc('image', cmap=cmap.name)
#
# E:\Edureka_Python-Course\edu-py\lib\site-packages\matplotlib\cm.py in get_cmap(name, lut)
#     202     if isinstance(name, colors.Colormap):
#     203         return name
# --> 204     cbook._check_in_list(sorted(_cmap_registry), name=name)
#     205     if lut is None:
#     206         return _cmap_registry[name]
#
# E:\Edureka_Python-Course\edu-py\lib\site-packages\matplotlib\cbook\__init__.py in _check_in_list(_values, **kwargs)
# ...
