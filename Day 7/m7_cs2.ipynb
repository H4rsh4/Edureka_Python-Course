# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score

# %%
df_raw = pd.read_csv('E:/Edureka_Python-Course/Data Sources/Day_7/horse.csv')

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   surgery                299 non-null    object
#  1   age                    299 non-null    object
#  2   hospital_number        299 non-null    int64
#  3   rectal_temp            239 non-null    float64
#  4   pulse                  275 non-null    float64
#  5   respiratory_rate       241 non-null    float64
#  6   temp_of_extremities    243 non-null    object
#  7   peripheral_pulse       230 non-null    object
#  8   mucous_membrane        252 non-null    object
#  9   capillary_refill_time  267 non-null    object
#  10  pain                   244 non-null    object
#  11  peristalsis            255 non-null    object
#  12  abdominal_distention   243 non-null    object
#  13  nasogastric_tube       195 non-null    object
#  14  nasogastric_reflux     193 non-null    object
#  15  nasogastric_reflux_ph  53 non-null     float64
#  16  rectal_exam_feces      197 non-null    object
#  17  abdomen                181 non-null    object
#  18  packed_cell_volume     270 non-null    float64
#  19  total_protein          266 non-null    float64
#  20  abdomo_appearance      134 non-null    object
#  21  abdomo_protein         101 non-null    float64
#  22  outcome                299 non-null    object
#  23  surgical_lesion        299 non-null    object
#  24  lesion_1               299 non-null    int64
#  25  lesion_2               299 non-null    int64
#  26  lesion_3               299 non-null    int64
#  27  cp_data                299 non-null    object
# dtypes: float64(7), int64(4), object(17)
# memory usage: 65.5+ KB

# %%
df_raw.head().transpose()
# Out:
#                                    0              1           2  \
# surgery                           no            yes          no
# age                            adult          adult       adult
# hospital_number               530101         534817      530334
# rectal_temp                     38.5           39.2        38.3
# pulse                             66             88          40
# respiratory_rate                  28             20          24
# temp_of_extremities             cool            NaN      normal
# peripheral_pulse             reduced            NaN      normal
# mucous_membrane                  NaN  pale_cyanotic   pale_pink
# capillary_refill_time     more_3_sec     less_3_sec  less_3_sec
# pain                    extreme_pain      mild_pain   mild_pain
# peristalsis                   absent         absent  hypomotile
# abdominal_distention          severe         slight        none
# nasogastric_tube                 NaN            NaN         NaN
# nasogastric_reflux               NaN            NaN         NaN
# nasogastric_reflux_ph            NaN            NaN         NaN
# rectal_exam_feces          decreased         absent      normal
# abdomen                distend_large          other      normal
# packed_cell_volume                45             50          33
# total_protein                    8.4             85         6.7
# abdomo_appearance                NaN         cloudy         NaN
# abdomo_protein                   NaN              2         NaN
# outcome                         died     euthanized       lived
# surgical_lesion                   no             no          no
# lesion_1                       11300           2208           0
# lesion_2                           0              0           0
# lesion_3                           0              0           0
# cp_data                           no             no         yes
#
#                                    3              4
# surgery                          yes             no
# age                            young          adult
# hospital_number              5290409         530255
# rectal_temp                     39.1           37.3
# pulse                            164            104
# respiratory_rate                  84             35
# temp_of_extremities             cold            NaN
# peripheral_pulse              normal            NaN
# mucous_membrane        dark_cyanotic  dark_cyanotic
# capillary_refill_time     more_3_sec     more_3_sec
# pain                       depressed            NaN
# peristalsis                   absent            NaN
# abdominal_distention          severe            NaN
# nasogastric_tube                none            NaN
# nasogastric_reflux      less_1_liter            NaN
# nasogastric_reflux_ph              5            NaN
# rectal_exam_feces          decreased            NaN
# abdomen                          NaN            NaN
# packed_cell_volume                48             74
# total_protein                    7.2            7.4
# abdomo_appearance      serosanguious            NaN
# abdomo_protein                   5.3            NaN
# outcome                         died           died
# surgical_lesion                  yes             no
# lesion_1                        2208           4300
# lesion_2                           0              0
# lesion_3                           0              0
# cp_data                          yes             no

# %%
any(df_raw.isnull())
# Out:
# True

# %%
df_raw.age.dtype == 'O'
# Out:
# True

# %%
#target = df_raw.outcome.copy()
#df_raw.drop('outcome', axis=1, inplace=True)

# %%
ip = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
ip.fit(df_raw)
transformed = ip.transform(df_raw)
df_num = pd.DataFrame(data=transformed, columns=df_raw.columns)
df_num.head().transpose()
# Out:
#                                    0              1           2  \
# surgery                           no            yes          no
# age                            adult          adult       adult
# hospital_number               530101         534817      530334
# rectal_temp                     38.5           39.2        38.3
# pulse                             66             88          40
# respiratory_rate                  28             20          24
# temp_of_extremities             cool           cool      normal
# peripheral_pulse             reduced         normal      normal
# mucous_membrane          normal_pink  pale_cyanotic   pale_pink
# capillary_refill_time     more_3_sec     less_3_sec  less_3_sec
# pain                    extreme_pain      mild_pain   mild_pain
# peristalsis                   absent         absent  hypomotile
# abdominal_distention          severe         slight        none
# nasogastric_tube              slight         slight      slight
# nasogastric_reflux              none           none        none
# nasogastric_reflux_ph              2              2           2
# rectal_exam_feces          decreased         absent      normal
# abdomen                distend_large          other      normal
# packed_cell_volume                45             50          33
# total_protein                    8.4             85         6.7
# abdomo_appearance             cloudy         cloudy      cloudy
# abdomo_protein                     2              2           2
# outcome                         died     euthanized       lived
# surgical_lesion                   no             no          no
# lesion_1                       11300           2208           0
# lesion_2                           0              0           0
# lesion_3                           0              0           0
# cp_data                           no             no         yes
#
#                                    3              4
# surgery                          yes             no
# age                            young          adult
# hospital_number              5290409         530255
# rectal_temp                     39.1           37.3
# pulse                            164            104
# respiratory_rate                  84             35
# temp_of_extremities             cold           cool
# peripheral_pulse              normal         normal
# mucous_membrane        dark_cyanotic  dark_cyanotic
# capillary_refill_time     more_3_sec     more_3_sec
# pain                       depressed      mild_pain
# peristalsis                   absent     hypomotile
# abdominal_distention          severe           none
# nasogastric_tube                none         slight
# nasogastric_reflux      less_1_liter           none
# nasogastric_reflux_ph              5              2
# rectal_exam_feces          decreased         absent
# abdomen                distend_large  distend_large
# packed_cell_volume                48             74
# total_protein                    7.2            7.4
# abdomo_appearance      serosanguious         cloudy
# abdomo_protein                   5.3              2
# outcome                         died           died
# surgical_lesion                  yes             no
# lesion_1                        2208           4300
# lesion_2                           0              0
# lesion_3                           0              0
# cp_data                          yes             no

# %%
for col in df_num.columns:
    print(f'{col}\t\t\t{df_num.isnull()[col].unique()}')
# Out:
# surgery			[False]
# age			[False]
# hospital_number			[False]
# rectal_temp			[False]
# pulse			[False]
# respiratory_rate			[False]
# temp_of_extremities			[False]
# peripheral_pulse			[False]
# mucous_membrane			[False]
# capillary_refill_time			[False]
# pain			[False]
# peristalsis			[False]
# abdominal_distention			[False]
# nasogastric_tube			[False]
# nasogastric_reflux			[False]
# nasogastric_reflux_ph			[False]
# rectal_exam_feces			[False]
# abdomen			[False]
# packed_cell_volume			[False]
# total_protein			[False]
# abdomo_appearance			[False]
# abdomo_protein			[False]
# outcome			[False]
# surgical_lesion			[False]
# lesion_1			[False]
# lesion_2			[False]
# lesion_3			[False]
# cp_data			[False]

# %%
categorical_cols = [col for col in df_num.columns if df_raw[col].dtype == 'O']

labelEncoders = {
    col : LabelEncoder() for col in categorical_cols
}

fitted_labelEncoders = {
    col : labelEncoders[col].fit(df_num[col]) for col in categorical_cols
}

for col in categorical_cols:
    df_num[col] = fitted_labelEncoders[col].transform(df_num[col])

df_num
# Out:
#      surgery  age hospital_number rectal_temp pulse respiratory_rate  \
# 0          0    0          530101        38.5    66               28
# 1          1    0          534817        39.2    88               20
# 2          0    0          530334        38.3    40               24
# 3          1    1         5290409        39.1   164               84
# 4          0    0          530255        37.3   104               35
# ..       ...  ...             ...         ...   ...              ...
# 294        1    0          533886          38   120               70
# 295        0    0          527702        37.2    72               24
# 296        1    0          529386        37.5    72               30
# 297        1    0          530612        36.5   100               24
# 298        1    0          534618        37.2    40               20
#
#      temp_of_extremities  peripheral_pulse  mucous_membrane  \
# 0                      1                 3                3
# 1                      1                 2                4
# 2                      2                 2                5
# 3                      0                 2                2
# 4                      1                 2                2
# ..                   ...               ...              ...
# 294                    0                 2                4
# 295                    1                 1                4
# 296                    0                 3                4
# 297                    1                 3                5
# 298                    1                 2                3
#
#      capillary_refill_time  ...  packed_cell_volume  total_protein  \
# 0                        2  ...                  45            8.4
# 1                        1  ...                  50             85
# 2                        1  ...                  33            6.7
# 3                        2  ...                  48            7.2
# 4                        2  ...                  74            7.4
# ..                     ...  ...                 ...            ...
# 294                      2  ...                  55             65
# 295                      2  ...                  44            6.5
# 296                      1  ...                  60            6.8
# 297                      1  ...                  50              6
# 298                      1  ...                  36             62
#
#      abdomo_appearance  abdomo_protein  outcome surgical_lesion  lesion_1  \
# 0                    1               2        0               0     11300
# 1                    1               2        1               0      2208
# 2                    1               2        2               0         0
# 3                    2             5.3        0               1      2208
# 4                    1               2        0               0      4300
# ..                 ...             ...      ...             ...       ...
# 294                  1               2        1               0      3205
# 295                  2             3.3        1               1      2208
# 296                  1               2        0               1      3205
# 297                  2             3.4        2               1      2208
# 298                  0               1        1               0      6112
#
#      lesion_2 lesion_3 cp_data
# 0           0        0       0
# 1           0        0       0
# 2           0        0       1
# 3           0        0       1
# 4           0        0       0
# ..        ...      ...     ...
# 294         0        0       0
# 295         0        0       1
# 296         0        0       0
# 297         0        0       1
# 298         0        0       0
#
# [299 rows x 28 columns]

# %%
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   surgery                299 non-null    int32
#  1   age                    299 non-null    int32
#  2   hospital_number        299 non-null    object
#  3   rectal_temp            299 non-null    object
#  4   pulse                  299 non-null    object
#  5   respiratory_rate       299 non-null    object
#  6   temp_of_extremities    299 non-null    int32
#  7   peripheral_pulse       299 non-null    int32
#  8   mucous_membrane        299 non-null    int32
#  9   capillary_refill_time  299 non-null    int32
#  10  pain                   299 non-null    int32
#  11  peristalsis            299 non-null    int32
#  12  abdominal_distention   299 non-null    int32
#  13  nasogastric_tube       299 non-null    int32
#  14  nasogastric_reflux     299 non-null    int32
#  15  nasogastric_reflux_ph  299 non-null    object
#  16  rectal_exam_feces      299 non-null    int32
#  17  abdomen                299 non-null    int32
#  18  packed_cell_volume     299 non-null    object
#  19  total_protein          299 non-null    object
#  20  abdomo_appearance      299 non-null    int32
#  21  abdomo_protein         299 non-null    object
#  22  outcome                299 non-null    int32
#  23  surgical_lesion        299 non-null    int32
#  24  lesion_1               299 non-null    object
#  25  lesion_2               299 non-null    object
#  26  lesion_3               299 non-null    object
#  27  cp_data                299 non-null    int32
# dtypes: int32(17), object(11)
# memory usage: 45.7+ KB

# %%
for col in df_num.columns:
    df_num[col] = pd.to_numeric(df_num[col])
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   surgery                299 non-null    int32
#  1   age                    299 non-null    int32
#  2   hospital_number        299 non-null    int64
#  3   rectal_temp            299 non-null    float64
#  4   pulse                  299 non-null    float64
#  5   respiratory_rate       299 non-null    float64
#  6   temp_of_extremities    299 non-null    int32
#  7   peripheral_pulse       299 non-null    int32
#  8   mucous_membrane        299 non-null    int32
#  9   capillary_refill_time  299 non-null    int32
#  10  pain                   299 non-null    int32
#  11  peristalsis            299 non-null    int32
#  12  abdominal_distention   299 non-null    int32
#  13  nasogastric_tube       299 non-null    int32
#  14  nasogastric_reflux     299 non-null    int32
#  15  nasogastric_reflux_ph  299 non-null    float64
#  16  rectal_exam_feces      299 non-null    int32
#  17  abdomen                299 non-null    int32
#  18  packed_cell_volume     299 non-null    float64
#  19  total_protein          299 non-null    float64
#  20  abdomo_appearance      299 non-null    int32
#  21  abdomo_protein         299 non-null    float64
#  22  outcome                299 non-null    int32
#  23  surgical_lesion        299 non-null    int32
#  24  lesion_1               299 non-null    int64
#  25  lesion_2               299 non-null    int64
#  26  lesion_3               299 non-null    int64
#  27  cp_data                299 non-null    int32
# dtypes: float64(7), int32(17), int64(4)
# memory usage: 45.7 KB

# %% [markdown]
# # All Numeric Data

# %%
features, target = df_num.drop('outcome', axis=1), df_num.outcome

# %%
trainX, testX, trainY, testY = train_test_split(features, target, random_state=58, test_size=0.2)

# %%
model_decisionTree = DecisionTreeClassifier()
model_randForest = RandomForestClassifier()
models = [model_decisionTree, model_randForest]

scores = []
for model in models:
    model.fit(trainX, trainY)
    y_predd = fitted_labelEncoders['outcome'].inverse_transform(model.predict(testX))
    y_truee = fitted_labelEncoders['outcome'].inverse_transform(testY)
    #print(y_pred)
    #print(y_true)
    score = accuracy_score(y_truee, y_predd)
    print(f'Accuracy of {model} : {score}')
# Out:
# Accuracy of DecisionTreeClassifier() : 0.6
# Accuracy of RandomForestClassifier() : 0.5666666666666667

# %%
df_num

# %%
target
